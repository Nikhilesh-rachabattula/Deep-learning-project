# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, roc_curve, auc

from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.mixed_precision import set_global_policy

# ⚙️ Enable mixed precision & XLA optimization
set_global_policy("mixed_float16")
tf.config.optimizer.set_jit(True)

# 📁 Dataset Paths
REAL_PATH = "/kaggle/input/deep-fake-detection-dfd-entire-original-dataset/DFD_original sequences"
FAKE_PATH = "/kaggle/input/deep-fake-detection-dfd-entire-original-dataset/DFD_manipulated_sequences/DFD_manipulated_sequences"

# ⚙️ Constants
IMG_SIZE = 128
FRAME_COUNT = 10
BATCH_SIZE = 32
CLASS_NAMES = ["Real", "Fake"]

# 🎞️ Extract frames from a video
def extract_frames(video_path, frame_count=10, output_size=(128, 128)):
    cap = cv2.VideoCapture(video_path)
    frames = []
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    step = max(total_frames // frame_count, 1)
    for i in range(frame_count):
        cap.set(cv2.CAP_PROP_POS_FRAMES, i * step)
        ret, frame = cap.read()
        if not ret:
            break
        frame = cv2.resize(frame, output_size)
        frames.append(frame)
    cap.release()
    return np.array(frames)

# 📄 Load video filenames
real_videos = sorted(os.listdir(REAL_PATH))
fake_videos = sorted(os.listdir(FAKE_PATH))

# ⚖️ Balance fake videos to real video count
fake_videos = fake_videos[:len(real_videos)]

# 🔀 70-30 Train-Test Split (Real and Fake Separately)
real_train, real_test = train_test_split(real_videos, test_size=0.3, random_state=42)
fake_train, fake_test = train_test_split(fake_videos, test_size=0.3, random_state=42)

# ✅ Final Counts
print(f"Real videos → Train: {len(real_train)}, Test: {len(real_test)}")
print(f"Fake videos → Train: {len(fake_train)}, Test: {len(fake_test)}")
# Out:
# Real videos → Train: 254, Test: 110
# Fake videos → Train: 254, Test: 110

# %%
# -------- Multiple Model Definitions -------- #

# 🔹 Model 1: MobileNetV2 with dropout and L2
def build_model_v1():
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
    base_model.trainable = True

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        BatchNormalization(),
        Dropout(0.3),
        Dense(256, activation='relu', kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.4),
        Dense(1, activation='sigmoid', dtype=tf.float32)
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# 🔹 Model 2: MobileNetV2 with lower dropout, no L2
def build_model_v2():
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
    base_model.trainable = True

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        BatchNormalization(),
        Dropout(0.2),
        Dense(128, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid', dtype=tf.float32)
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

def build_model_v3():
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
    base_model.trainable = True

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        BatchNormalization(),
        Dropout(0.5),
        Dense(256, activation='relu', kernel_regularizer=l2(0.02)),
        Dropout(0.5),
        Dense(1, activation='sigmoid', dtype=tf.float32)
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# -------- Data Augmentation Layer -------- #
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
    tf.keras.layers.RandomBrightness(0.1)
])

# %%
# -------- Helper to load video frames -------- #
def load_videos(video_list, label, base_path):
    X, y, video_ids = [], [], []

    for vid in tqdm(video_list, desc=f"Loading {'Real' if label==0 else 'Fake'} videos"):
        frames = extract_frames(os.path.join(base_path, vid), frame_count=FRAME_COUNT)
        if len(frames) < FRAME_COUNT:
            continue
        for frame in frames:
            frame_resized = tf.image.resize(frame, (IMG_SIZE, IMG_SIZE)).numpy()
            X.append(frame_resized)
            y.append(label)
            video_ids.append(vid)
    
    return np.array(X, dtype=np.float32), np.array(y, dtype=np.float32), np.array(video_ids)

# -------- Load Training Data -------- #
X_real, y_real, _ = load_videos(real_train, 0, REAL_PATH)
X_fake, y_fake, _ = load_videos(fake_train, 1, FAKE_PATH)

X_train = np.concatenate((X_real, X_fake), axis=0)
y_train = np.concatenate((y_real, y_fake), axis=0)

# Normalize
X_train /= 255.0

# -------- Apply Data Augmentation -------- #
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_ds = train_ds.shuffle(buffer_size=len(X_train))
train_ds = train_ds.map(lambda x, y: (data_augmentation(x), y), num_parallel_calls=tf.data.AUTOTUNE)
train_ds = train_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# -------- Callbacks -------- #
early_stopping = EarlyStopping(monitor="loss", patience=7, restore_best_weights=True)

# -------- Train Multiple Models -------- #
models = {
    "Model_V1": build_model_v1(),
    "Model_V2": build_model_v2(),
    "Model_V3": build_model_v3(),
}

histories = {}

for name, model in models.items():
    print(f"\n🔧 Training {name}...")
    history = model.fit(train_ds, epochs=20, callbacks=[early_stopping])
    histories[name] = (model, history)





# -------- Load Training Data for Evaluation -------- #
X_real_train_eval, y_real_train_eval, vid_ids_real_train = load_videos(real_train, 0, REAL_PATH)
X_fake_train_eval, y_fake_train_eval, vid_ids_fake_train = load_videos(fake_train, 1, FAKE_PATH)

X_train_eval = np.concatenate((X_real_train_eval, X_fake_train_eval), axis=0)
y_train_eval = np.concatenate((y_real_train_eval, y_fake_train_eval), axis=0)
video_ids_train = np.concatenate((vid_ids_real_train, vid_ids_fake_train), axis=0)

X_train_eval /= 255.0

# -------- Accuracy & Loss Only -------- #
from collections import defaultdict

print("\n🔍 Evaluating on Training Data...")

for name, (model, _) in histories.items():
    print(f"\n📊 Model: {name}")

    # Frame-level prediction
    y_probs = model.predict(X_train_eval, batch_size=BATCH_SIZE, verbose=0)
    y_pred = (y_probs > 0.5).astype(int).flatten()

    # Frame-level accuracy and loss
    loss, acc = model.evaluate(X_train_eval, y_train_eval, verbose=0)
    print(f"✅ Frame-Level Accuracy: {acc:.4f}")
    print(f"🔻 Frame-Level Loss: {loss:.4f}")

    # Video-level accuracy
    video_preds = defaultdict(list)
    video_labels = {}

    for i in range(len(video_ids_train)):
        video_preds[video_ids_train[i]].append(y_probs[i])
        video_labels[video_ids_train[i]] = int(y_train_eval[i])

    y_video_pred, y_video_true = [], []

    for vid, probs in video_preds.items():
        avg_prob = np.mean(probs)
        pred_label = int(avg_prob > 0.5)
        y_video_pred.append(pred_label)
        y_video_true.append(video_labels[vid])

    video_acc = accuracy_score(y_video_true, y_video_pred)
    print(f"🎬 Video-Level Accuracy: {video_acc:.4f}")





# -------- Load Test Data -------- #
X_real_test, y_real_test, vid_ids_real = load_videos(real_test, 0, REAL_PATH)
X_fake_test, y_fake_test, vid_ids_fake = load_videos(fake_test, 1, FAKE_PATH)

X_test = np.concatenate((X_real_test, X_fake_test), axis=0)
y_test = np.concatenate((y_real_test, y_fake_test), axis=0)
video_ids = np.concatenate((vid_ids_real, vid_ids_fake), axis=0)

# Normalize
X_test = X_test / 255.0

# -------- Evaluate All Models -------- #
from collections import defaultdict
import pandas as pd
from tensorflow.keras.losses import BinaryCrossentropy

results = []

for name, (model, history) in histories.items():
    print(f"\n📊 Evaluating {name}...")

    # Frame-level prediction
    y_probs = model.predict(X_test, batch_size=BATCH_SIZE)
    y_pred = (y_probs > 0.5).astype(int).flatten()

    # -------- Frame-level Metrics -------- #
    acc = accuracy_score(y_test, y_pred)
    cm = confusion_matrix(y_test, y_pred)
    report = classification_report(y_test, y_pred, target_names=CLASS_NAMES)
    fpr, tpr, _ = roc_curve(y_test, y_probs)
    roc_auc = auc(fpr, tpr)

    # Frame-level loss
    loss_fn = BinaryCrossentropy()
    frame_loss = loss_fn(tf.convert_to_tensor(y_test, dtype=tf.float32),
                         tf.convert_to_tensor(y_probs.flatten(), dtype=tf.float32)).numpy()

    print(f"✅ Frame-Level Accuracy: {acc:.4f}")
    print(f"📉 Frame-Level Loss: {frame_loss:.4f}")
    print("📋 Classification Report:\n", report)

    # Confusion Matrix
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.title(f"{name} - Frame-Level Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

    # ROC Curve
    plt.figure(figsize=(5, 4))
    plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
    plt.plot([0, 1], [0, 1], 'k--')
    plt.title(f"{name} - ROC Curve")
    plt.xlabel("FPR")
    plt.ylabel("TPR")
    plt.legend()
    plt.grid(True)
    plt.show()

    # -------- Video-Level Evaluation -------- #
    video_preds = defaultdict(list)
    video_labels = {}

    for i in range(len(video_ids)):
        video_preds[video_ids[i]].append(y_probs[i])
        video_labels[video_ids[i]] = int(y_test[i])  # All frames of video have same label

    y_video_pred, y_video_true, video_probs = [], [], []

    for vid, probs in video_preds.items():
        avg_prob = np.mean(probs)
        pred_label = int(avg_prob > 0.5)

        y_video_pred.append(pred_label)
        y_video_true.append(video_labels[vid])
        video_probs.append(avg_prob)

    video_acc = accuracy_score(y_video_true, y_video_pred)
    video_cm = confusion_matrix(y_video_true, y_video_pred)
    video_report = classification_report(y_video_true, y_video_pred, target_names=CLASS_NAMES)

    # 📊 Video-Level Confusion Matrix
    plt.figure(figsize=(5, 4))
    sns.heatmap(video_cm, annot=True, fmt="d", cmap="Greens", xticklabels=CLASS_NAMES, yticklabels=CLASS_NAMES)
    plt.title(f"{name} - Video-Level Confusion Matrix")
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()



    # ROC Curve for Video-Level
    video_fpr, video_tpr, _ = roc_curve(y_video_true, video_probs)
    video_roc_auc = auc(video_fpr, video_tpr)

    plt.figure(figsize=(5, 4))
    plt.plot(video_fpr, video_tpr, label=f"AUC = {video_roc_auc:.2f}", color="green")
    plt.plot([0, 1], [0, 1], 'k--')
    plt.title(f"{name} - Video-Level ROC Curve")
    plt.xlabel("FPR")
    plt.ylabel("TPR")
    plt.legend()
    plt.grid(True)
    plt.show()


    # Video-level loss
    video_loss = loss_fn(tf.convert_to_tensor(y_video_true, dtype=tf.float32),
                         tf.convert_to_tensor(video_probs, dtype=tf.float32)).numpy()

    print(f"\n🎬 Video-Level Accuracy: {video_acc:.4f}")
    print(f"📉 Video-Level Loss: {video_loss:.4f}")
    print("📋 Video-Level Classification Report:\n", video_report)

    # Save results for comparison
    results.append({
        "Model": name,
        "Frame Accuracy": acc,
        "Frame Loss": frame_loss,
        "Video Accuracy": video_acc,
        "Video Loss": video_loss,
        "ROC AUC": roc_auc
    })

# -------- Summary & Visual Comparison -------- #
results_df = pd.DataFrame(results).sort_values(by="Video Accuracy", ascending=False)

print("\n📌 Final Summary of Model Results:")
print(results_df)

# 📊 Frame vs Video Accuracy
plt.figure(figsize=(10, 5))
bar_width = 0.35
x = np.arange(len(results_df["Model"]))

plt.bar(x - bar_width / 2, results_df["Frame Accuracy"], width=bar_width, label="Frame Accuracy")
plt.bar(x + bar_width / 2, results_df["Video Accuracy"], width=bar_width, label="Video Accuracy")
plt.xticks(x, results_df["Model"])
plt.ylabel("Accuracy")
plt.title("Model Comparison: Frame vs Video Accuracy")
plt.legend()
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# 📉 Frame vs Video Loss
plt.figure(figsize=(10, 5))
plt.bar(x - bar_width / 2, results_df["Frame Loss"], width=bar_width, label="Frame Loss", color='skyblue')
plt.bar(x + bar_width / 2, results_df["Video Loss"], width=bar_width, label="Video Loss", color='salmon')
plt.xticks(x, results_df["Model"])
plt.ylabel("Loss")
plt.title("Model Comparison: Frame vs Video Loss")
plt.legend()
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# 📊 ROC AUC Comparison
plt.figure(figsize=(7, 4))
plt.bar(results_df["Model"], results_df["ROC AUC"], color='orange')
plt.ylabel("AUC Score")
plt.title("ROC AUC of Models")
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# 📈 Training Curves
plt.figure(figsize=(14, 5))
for name, (_, history) in histories.items():
    acc = history.history['accuracy']
    loss = history.history['loss']
    epochs = range(1, len(acc) + 1)

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, label=f'{name} Acc')

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, label=f'{name} Loss')

plt.subplot(1, 2, 1)
plt.title("Training Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()


# -------- Final Model Comparison -------- #
results_df = pd.DataFrame(results)

# Reorder columns for readability
results_df = results_df[[
    "Model", 
    "Frame Accuracy", "Frame Loss", 
    "Video Accuracy", "Video Loss", 
    "ROC AUC"
]]

# Sort by Video Accuracy
results_df_sorted = results_df.sort_values(by="Video Accuracy", ascending=False)

print("\n🔚 Final Results Summary (sorted by Video Accuracy):\n")
print(results_df_sorted.to_string(index=False))
# Out:
# Loading Real videos: 100%|██████████| 254/254 [15:15<00:00,  3.60s/it]
# Loading Fake videos: 100%|██████████| 254/254 [15:18<00:00,  3.62s/it]
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# 🔧 Training Model_V1...
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745570946.542407      94 service.cc:148] XLA service 0x788414005650 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745570946.544530      94 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1745570946.544552      94 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1745570946.586557      94 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1745570946.684764      94 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 113s 266ms/step - accuracy: 0.5064 - loss: 5.0814
# Epoch 2/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.5473 - loss: 4.4814
# Epoch 3/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.5724 - loss: 4.0277
# Epoch 4/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 87ms/step - accuracy: 0.6191 - loss: 3.6273
# Epoch 5/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.6469 - loss: 3.3138
# Epoch 6/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 85ms/step - accuracy: 0.6351 - loss: 3.0800
# Epoch 7/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 85ms/step - accuracy: 0.6595 - loss: 2.8158
# Epoch 8/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.6769 - loss: 2.5735
# Epoch 9/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 87ms/step - accuracy: 0.6635 - loss: 2.3969
# Epoch 10/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.6967 - loss: 2.1848
# Epoch 11/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.6957 - loss: 2.0046
# Epoch 12/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.6775 - loss: 1.8881
# Epoch 13/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.6918 - loss: 1.7095
# Epoch 14/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.6879 - loss: 1.5910
# Epoch 15/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.7111 - loss: 1.4717
# Epoch 16/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 87ms/step - accuracy: 0.7011 - loss: 1.3674
# Epoch 17/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.7061 - loss: 1.2611
# Epoch 18/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 87ms/step - accuracy: 0.7200 - loss: 1.1710
# Epoch 19/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 85ms/step - accuracy: 0.7067 - loss: 1.0931
# Epoch 20/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.7061 - loss: 1.0367
#
# 🔧 Training Model_V2...
# Epoch 1/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 101s 236ms/step - accuracy: 0.5223 - loss: 0.8968
# Epoch 2/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.5741 - loss: 0.7934
# Epoch 3/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.5920 - loss: 0.7123
# Epoch 4/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 87ms/step - accuracy: 0.6101 - loss: 0.7130
# Epoch 5/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.6344 - loss: 0.6573
# Epoch 6/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 87ms/step - accuracy: 0.6422 - loss: 0.6362
# Epoch 7/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.6780 - loss: 0.5730
# Epoch 8/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 87ms/step - accuracy: 0.6893 - loss: 0.5409
# Epoch 9/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.6924 - loss: 0.5507
# Epoch 10/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.7009 - loss: 0.5193
# Epoch 11/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.7056 - loss: 0.4983
# Epoch 12/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 85ms/step - accuracy: 0.7024 - loss: 0.4968
# Epoch 13/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 87ms/step - accuracy: 0.7080 - loss: 0.4994
# Epoch 14/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.7185 - loss: 0.4730
# Epoch 15/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 87ms/step - accuracy: 0.6939 - loss: 0.5221
# Epoch 16/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.7132 - loss: 0.4627
# Epoch 17/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.7035 - loss: 0.4782
# Epoch 18/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 87ms/step - accuracy: 0.7324 - loss: 0.4490
# Epoch 19/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 84ms/step - accuracy: 0.7187 - loss: 0.4528
# Epoch 20/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.7055 - loss: 0.4757
#
# 🔧 Training Model_V3...
# Epoch 1/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 100s 240ms/step - accuracy: 0.5087 - loss: 9.3081
# Epoch 2/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.5372 - loss: 7.8895
# Epoch 3/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 86ms/step - accuracy: 0.5647 - loss: 6.7877
# Epoch 4/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.5981 - loss: 5.9060
# Epoch 5/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 85ms/step - accuracy: 0.6068 - loss: 5.1615
# Epoch 6/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 14s 85ms/step - accuracy: 0.6422 - loss: 4.5241
# Epoch 7/20
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 84ms/step - accuracy: 0.6578 - loss: 3.9711
# Loading Real videos: 100%|██████████| 254/254 [15:07<00:00,  3.57s/it]
# Loading Fake videos: 100%|██████████| 254/254 [15:21<00:00,  3.63s/it]
# 🔍 Evaluating on Training Data...
#
# 📊 Model: Model_V1
# ✅ Frame-Level Accuracy: 0.9422
# 🔻 Frame-Level Loss: 0.6845
# 🎬 Video-Level Accuracy: 0.9566
#
# 📊 Model: Model_V2
# ✅ Frame-Level Accuracy: 0.9314
# 🔻 Frame-Level Loss: 0.2141
# 🎬 Video-Level Accuracy: 0.9428
#
# 📊 Model: Model_V3
# ✅ Frame-Level Accuracy: 0.6018
# 🔻 Frame-Level Loss: 7.9292
# 🎬 Video-Level Accuracy: 0.6036
# Loading Real videos: 100%|██████████| 110/110 [06:44<00:00,  3.68s/it]
# Loading Fake videos: 100%|██████████| 110/110 [06:48<00:00,  3.72s/it]
# 📊 Evaluating Model_V1...
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step
# ✅ Frame-Level Accuracy: 0.8895
# 📉 Frame-Level Loss: 0.3135
# 📋 Classification Report:
#                precision    recall  f1-score   support
#
#         Real       0.93      0.84      0.88      1100
#         Fake       0.86      0.93      0.89      1100
#
#     accuracy                           0.89      2200
#    macro avg       0.89      0.89      0.89      2200
# weighted avg       0.89      0.89      0.89      2200
# 🎬 Video-Level Accuracy: 0.9091
# 📉 Video-Level Loss: 0.2748
# 📋 Video-Level Classification Report:
#                precision    recall  f1-score   support
#
#         Real       0.97      0.85      0.90       110
#         Fake       0.86      0.97      0.91       110
#
#     accuracy                           0.91       220
#    macro avg       0.92      0.91      0.91       220
# weighted avg       0.92      0.91      0.91       220
#
#
# 📊 Evaluating Model_V2...
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step
# ✅ Frame-Level Accuracy: 0.8814
# 📉 Frame-Level Loss: 0.3482
# 📋 Classification Report:
#                precision    recall  f1-score   support
#
#         Real       0.99      0.77      0.87      1100
#         Fake       0.81      0.99      0.89      1100
#
#     accuracy                           0.88      2200
#    macro avg       0.90      0.88      0.88      2200
# weighted avg       0.90      0.88      0.88      2200
# 🎬 Video-Level Accuracy: 0.8955
# 📉 Video-Level Loss: 0.3115
# 📋 Video-Level Classification Report:
#                precision    recall  f1-score   support
#
#         Real       1.00      0.79      0.88       110
#         Fake       0.83      1.00      0.91       110
#
#     accuracy                           0.90       220
#    macro avg       0.91      0.90      0.89       220
# weighted avg       0.91      0.90      0.89       220
#
#
# 📊 Evaluating Model_V3...
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step
# ✅ Frame-Level Accuracy: 0.5809
# 📉 Frame-Level Loss: 0.7221
# 📋 Classification Report:
#                precision    recall  f1-score   support
#
#         Real       0.70      0.28      0.40      1100
#         Fake       0.55      0.88      0.68      1100
#
#     accuracy                           0.58      2200
#    macro avg       0.63      0.58      0.54      2200
# weighted avg       0.63      0.58      0.54      2200
# 🎬 Video-Level Accuracy: 0.5682
# 📉 Video-Level Loss: 0.6978
# 📋 Video-Level Classification Report:
#                precision    recall  f1-score   support
#
#         Real       0.73      0.22      0.34       110
#         Fake       0.54      0.92      0.68       110
#
#     accuracy                           0.57       220
#    macro avg       0.63      0.57      0.51       220
# weighted avg       0.63      0.57      0.51       220
#
#
# 📌 Final Summary of Model Results:
#       Model  Frame Accuracy  Frame Loss  Video Accuracy  Video Loss   ROC AUC
# 0  Model_V1        0.889545    0.313502        0.909091    0.274788  0.922281
# 1  Model_V2        0.881364    0.348174        0.895455    0.311547  0.928517
# 2  Model_V3        0.580909    0.722074        0.568182    0.697777  0.662300
# 🔚 Final Results Summary (sorted by Video Accuracy):
#
#    Model  Frame Accuracy  Frame Loss  Video Accuracy  Video Loss  ROC AUC
# Model_V1        0.889545    0.313502        0.909091    0.274788 0.922281
# Model_V2        0.881364    0.348174        0.895455    0.311547 0.928517
# Model_V3        0.580909    0.722074        0.568182    0.697777 0.662300
